# %%
import pandas as pd
import numpy as np
import spacy
import re
# !python -m spacy download pt_core_news_md

pt_spacy = spacy.load('pt_core_news_md')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42.4 MB 1.5 MB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_md')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/viniciusrpb/cic0269_natural_language_processing/main/datasets/corpora/training.csv").head(10)
df
# Out:
#    Id                                               text  Expected
# 0   0  Ótima localização, bom atendimento, bom sinal ...         1
# 1   1  O hotel é bem localizado e silencioso, o que c...         1
# 2   2  O hotel é muito bom. O atendimento é excelente...         2
# 3   3  Hotel antigo, mal conservado e mal reformado, ...         0
# 4   4  Hotel bem localizado, perto de dois shopping, ...         2
# 5   5  Hotel 3 estrelas com muitos problemas de manut...         0
# 6   6  O hotel cumpre ao que se propõe, pelo preço ac...         2
# 7   7  Hotel apesar de bem localizado tem uma péssima...         0
# 8   8  Ótima localização, perto do Setor Bancário Nor...         2
# 9   9  Os hotéis da Rede Bittar em Brasília servem ao...         2

# %%
def pre_proc(row):
  texto = row.text.lower()
  # texto = re.sub("[,\.0-9]", "", texto)
  row.text = pt_spacy(texto)
  return row

d = dict()

def pos(row):
  for wrd in row.text:
    d[str(wrd)] = wrd.pos_

df_proc = df.apply(pre_proc, axis=1)
df_proc.apply(pos, axis=1)
s = pd.Series(d)

s.to_csv("tag.csv")
s
